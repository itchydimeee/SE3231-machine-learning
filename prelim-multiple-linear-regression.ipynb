# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv("csv/gameandgrade.csv")


# Clean Data because of typo error on the csv file with Grade having a double dot (eg. 92..00)
data = data[~data["Grade"].astype(str).str.contains(r"\.\..", regex=True)]
# Convert Grade column into Numeric Value (invalid values and non-numeric values = NaN)
data["Grade"] = pd.to_numeric(data["Grade"], errors="coerce")
# Remove NaN (previously invalid and non-numeric values) fron the data set
data.dropna(subset=["Grade"], inplace=True)

# Remove duplicate values
data = data[data.duplicated() == False]
data.duplicated().sum()

data.head()
# Out:
#    Sex  School Code  Playing Years  Playing Often  Playing Hours  \
# 0    0            1              1              2              1
# 1    1            1              1              3              1
# 2    0            1              0              0              0
# 3    0            1              3              5              1
# 4    1            1              1              1              2
#
#    Playing Games  Parent Revenue  Father Education  Mother Education  Grade
# 0              1               4                 4                 5   77.5
# 1              1               1                 3                 3   83.0
# 2              0               1                 3                 3   80.0
# 3              1               2                 2                 3   45.0
# 4              1               1                 3                 4   85.0

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 753 entries, 0 to 769
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Sex               753 non-null    int64
#  1   School Code       753 non-null    int64
#  2   Playing Years     753 non-null    int64
#  3   Playing Often     753 non-null    int64
#  4   Playing Hours     753 non-null    int64
#  5   Playing Games     753 non-null    int64
#  6   Parent Revenue    753 non-null    int64
#  7   Father Education  753 non-null    int64
#  8   Mother Education  753 non-null    int64
#  9   Grade             753 non-null    float64
# dtypes: float64(1), int64(9)
# memory usage: 64.7 KB
#               Sex  School Code  Playing Years  Playing Often  Playing Hours  \
# count  753.000000   753.000000     753.000000     753.000000     753.000000
# mean     0.509960     4.887118       1.620186       2.293493       1.521912
# std      0.500233     2.994988       1.402587       1.915134       1.333832
# min      0.000000     1.000000       0.000000       0.000000       0.000000
# 25%      0.000000     2.000000       0.000000       0.000000       0.000000
# 50%      1.000000     4.000000       1.000000       2.000000       1.000000
# 75%      1.000000     8.000000       3.000000       4.000000       2.000000
# max      1.000000    11.000000       4.000000       5.000000       5.000000
#
#        Playing Games  Parent Revenue  Father Education  Mother Education  \
# count     753.000000      753.000000        753.000000        753.000000
# mean        0.722444        1.867198          3.699867          3.385126
# std         0.451049        1.049772          1.169294          1.165959
# min         0.000000        0.000000          0.000000          0.000000
# 25%         0.000000        1.000000          3.000000          2.000000
# 50%         1.000000        2.000000          4.000000          3.000000
# 75%         1.000000        3.000000          4.000000          4.000000
# max         2.000000        4.000000          6.000000          6.000000
#
#             Grade
# count  753.000000
# mean    77.134834
# std     16.415164
# min     33.000000
# 25%     65.000000
# 50%     80.000000
# 75%     90.000000
# max    100.000000

# %%
X = data[["Playing Years", "Playing Hours", "Playing Games", "Father Education", "Mother Education"]]
Y = data[["Grade"]]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
print(f"Intercept (b): {model.intercept_}") 
coefficients = pd.DataFrame(model.coef_[0], X.columns, columns=['Coefficient'])
print(coefficients)
# Out:
# Intercept (b): [60.67687969]
#                   Coefficient
# Playing Years        0.114250
# Playing Hours       -0.729219
# Playing Games       -2.818728
# Father Education     2.252212
# Mother Education     3.294952

# %%
Y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)
print(f"Mean Squared Error: {mse:.2f}")
print(f"r2 Score: {r2:.2f}")
# Out:
# Mean Squared Error: 227.47
# r2 Score: 0.23

# %%
plt.figure(figsize=(8, 6))

# Actual Values
sns.scatterplot(x=Y_test.values.flatten(), y=Y_test.values.flatten(), color="blue", label="Actual", alpha=0.6) 
# Predicted Values
sns.scatterplot(x=Y_test.values.flatten(), y=Y_pred.flatten(), color="red", label="Predicted", alpha=0.6)  

# Reference Line
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], color="black", linestyle="--", label="Perfect Fit")

plt.xlabel("Actual Scores")
plt.ylabel("Predicted Scores")
plt.title("Multiple Linear Regression: Actual vs Predicted")
plt.legend()
plt.show()

# %%
coefficients = pd.DataFrame(model.coef_[0], X.columns, columns=['Coefficient'])
coefficients = coefficients.sort_values(by="Coefficient", ascending=False)
print(coefficients)
# Out:
#                   Coefficient
# Mother Education     3.294952
# Father Education     2.252212
# Playing Years        0.114250
# Playing Hours       -0.729219
# Playing Games       -2.818728

# %%
r2_train = r2_score(Y_train, model.predict(X_train))
r2_test = r2_score(Y_test, Y_pred)

print(f"R² Training Data: {r2_train:.4f}")
print(f"R² Test Data: {r2_test:.4f}")
# Out:
# R² Training Data: 0.1324
# R² Test Data: 0.2288
